# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)

# %%
url = "http://ergast.com/api/f1/2008/5/driverStandings.json"

# %%
#response object
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
type(data)
# Out:
# list

# %%
def get_racer_info(data):
    new_data=[]
    for racer in data:
        racer_dict={}
        racer_name = f"{racer['Driver']['givenName']} {racer['Driver']['familyName']}"
        
        racer_dict[racer_name]={
            'first_name':racer['Driver']['givenName'],
            'last_name':racer['Driver']['familyName'],
            'position':racer['position'],
            'wins':racer['wins'],
            'DOB':racer['Driver']['dateOfBirth'],
            'nationality':racer['Driver']['nationality'],
            'contructor':racer['Constructors'][0]['name']
        }
        new_data.append(racer_dict)
    return new_data

get_racer_info(data)
# Out:
# [{'Kimi Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'contructor': 'Ferrari'}},
#  {'Felipe Massa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'contructor': 'Ferrari'}},
#  {'Lewis Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'contructor': 'McLaren'}},
#  {'Robert Kubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'contructor': 'BMW Sauber'}},
#  {'Nick Heidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year,r):
    url = f"http://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
#     if not response.ok:
    if not response.json()["MRData"]["StandingsTable"]["StandingsLists"]:
        return "We had an error loading your data likely the year or round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2022,4)
# Out:
# 'We had an error loading your data likely the year or round is not in the database'

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
import requests, json

# %%
url = "https://pokeapi.co/api/v2/pokemon/charizard"

# %%
response_charizard = requests.get(url)
print(response_charizard)
# Out:
# <Response [200]>

# %%
response_charizard.ok
# Out:
# True

# %%
response_charizard.json()
# Out:
# {'abilities': [{'ability': {'name': 'blaze',
#     'url': 'https://pokeapi.co/api/v2/ability/66/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'solar-power',
#     'url': 'https://pokeapi.co/api/v2/ability/94/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 240,
#  'forms': [{'name': 'charizard',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/6/'}],
#  'game_indices': [{'game_index': 180,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 180,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 180,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 6,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 6,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 6,
# ...

# %%
type(response_charizard.json())
# Out:
# dict

# %%
charizard_data_name = response_charizard.json()["forms"][0]["name"]
print(charizard_data_name)

charizard_data_ability = response_charizard.json()["abilities"][0]["ability"]["name"]
print(charizard_data_ability)

charizard_data_exp = response_charizard.json()["base_experience"]
print(charizard_data_exp)

charizard_data_shiny = response_charizard.json()["sprites"]["front_shiny"]
print(charizard_data_shiny)

charizard = [charizard_data_name, charizard_data_ability, charizard_data_exp, charizard_data_shiny]

print(charizard)
# Out:
# charizard
# blaze
# 240
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png
# ['charizard', 'blaze', 240, 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png']

# %%
url = "https://pokeapi.co/api/v2/pokemon/mew"

# %%
response_mew = requests.get(url)
print(response_mew)
# Out:
# <Response [200]>

# %%
response_mew.json()
# Out:
# {'abilities': [{'ability': {'name': 'synchronize',
#     'url': 'https://pokeapi.co/api/v2/ability/28/'},
#    'is_hidden': False,
#    'slot': 1}],
#  'base_experience': 270,
#  'forms': [{'name': 'mew',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/151/'}],
#  'game_indices': [{'game_index': 21,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 21,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 21,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 151,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 151,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 151,
#    'version': {'name': 'crystal',
#     'url': 'https://pokeapi.co/api/v2/version/6/'}},
#   {'game_index': 151,
# ...

# %%
mew_data_name = response_mew.json()["forms"][0]["name"]
print(mew_data_name)

mew_data_ability = response_mew.json()["abilities"][0]["ability"]["name"]
print(mew_data_ability)

mew_data_exp = response_mew.json()["base_experience"]
print(mew_data_exp)

mew_data_shiny = response_mew.json()["sprites"]["front_shiny"]
print(mew_data_shiny)

mew = [mew_data_name, mew_data_ability, mew_data_exp, mew_data_shiny]

print(mew)
# Out:
# mew
# synchronize
# 270
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png
# ['mew', 'synchronize', 270, 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png']

# %%
url = "https://pokeapi.co/api/v2/pokemon/blastoise"

# %%
response_blastoise = requests.get(url)
print(response_blastoise)
# Out:
# <Response [200]>

# %%
response_blastoise.json()
# Out:
# {'abilities': [{'ability': {'name': 'torrent',
#     'url': 'https://pokeapi.co/api/v2/ability/67/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'rain-dish',
#     'url': 'https://pokeapi.co/api/v2/ability/44/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 239,
#  'forms': [{'name': 'blastoise',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/9/'}],
#  'game_indices': [{'game_index': 28,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 28,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 28,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 9,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 9,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 9,
# ...

# %%
blastoise_data_name = response_blastoise.json()["forms"][0]["name"]
print(blastoise_data_name)

blastoise_data_ability = response_blastoise.json()["abilities"][1]["ability"]["name"]
print(blastoise_data_ability)

blastoise_data_exp = response_blastoise.json()["base_experience"]
print(blastoise_data_exp)

blastoise_data_shiny = response_blastoise.json()["sprites"]["front_shiny"]
print(blastoise_data_shiny)

blastoise = [blastoise_data_name, blastoise_data_ability, blastoise_data_exp, blastoise_data_shiny]

print(blastoise)
# Out:
# blastoise
# rain-dish
# 239
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png
# ['blastoise', 'rain-dish', 239, 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png']

# %%
url = "https://pokeapi.co/api/v2/pokemon/dragonite"

# %%
response_dragonite = requests.get(url)
print(response_dragonite)
# Out:
# <Response [200]>

# %%
response_dragonite.json()
# Out:
# {'abilities': [{'ability': {'name': 'inner-focus',
#     'url': 'https://pokeapi.co/api/v2/ability/39/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'multiscale',
#     'url': 'https://pokeapi.co/api/v2/ability/136/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 270,
#  'forms': [{'name': 'dragonite',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/149/'}],
#  'game_indices': [{'game_index': 66,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 66,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 66,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 149,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 149,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 149,
# ...

# %%
dragonite_data_name = response_dragonite.json()["forms"][0]["name"]
print(dragonite_data_name)

dragonite_data_ability = response_dragonite.json()["abilities"][0]["ability"]["name"]
print(dragonite_data_ability)

dragonite_data_exp = response_dragonite.json()["base_experience"]
print(dragonite_data_exp)

dragonite_data_shiny = response_dragonite.json()["sprites"]["front_shiny"]
print(dragonite_data_shiny)

dragonite = [mew_data_name, mew_data_ability, mew_data_exp, mew_data_shiny]

print(dragonite)
# Out:
# dragonite
# inner-focus
# 270
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/149.png
# ['mew', 'synchronize', 270, 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png']

# %%
url = "https://pokeapi.co/api/v2/pokemon/venusaur"

# %%
response_venusaur = requests.get(url)
print(response_venusaur)
# Out:
# <Response [200]>

# %%
response_venusaur.json()
# Out:
# {'abilities': [{'ability': {'name': 'overgrow',
#     'url': 'https://pokeapi.co/api/v2/ability/65/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'chlorophyll',
#     'url': 'https://pokeapi.co/api/v2/ability/34/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 236,
#  'forms': [{'name': 'venusaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/3/'}],
#  'game_indices': [{'game_index': 154,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 154,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 154,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 3,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 3,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 3,
# ...

# %%
venusaur_data_name = response_venusaur.json()["forms"][0]["name"]
print(venusaur_data_name)

venusaur_data_ability = response_venusaur.json()["abilities"][1]["ability"]["name"]
print(venusaur_data_ability)

venusaur_data_exp = response_venusaur.json()["base_experience"]
print(venusaur_data_exp)

venusaur_data_shiny = response_venusaur.json()["sprites"]["front_shiny"]
print(venusaur_data_shiny)

venusaur = [mew_data_name, mew_data_ability, mew_data_exp, mew_data_shiny]

print(venusaur)
# Out:
# venusaur
# chlorophyll
# 236
# https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/3.png
# ['mew', 'synchronize', 270, 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png']

# %%
pokemon_list = [charizard, mew, blastoise, dragonite, venusaur]
pokemon_list
# Out:
# [['charizard',
#   'blaze',
#   240,
#   'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/6.png'],
#  ['mew',
#   'synchronize',
#   270,
#   'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png'],
#  ['blastoise',
#   'rain-dish',
#   239,
#   'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/9.png'],
#  ['mew',
#   'synchronize',
#   270,
#   'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png'],
#  ['mew',
#   'synchronize',
#   270,
#   'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/151.png']]
